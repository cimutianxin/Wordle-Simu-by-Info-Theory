# %%
import numpy as np
import pandas as pd
import os

# %%
# import word list
with open("data/allowed_words.txt", "r") as f:
    long_word_list = [word.strip() for word in f.readlines()]
with open("data/possible_words.txt", "r") as f:
    short_word_list = [word.strip() for word in f.readlines()]

# generate reply list
reply_list = []
for i in range(3):
    for j in range(3):
        for k in range(3):
            for l in range(3):
                for m in range(3):
                    reply_list.append([i, j, k, l, m])

# %%
# split the word into letters
def split_word(word):
    return [letter for letter in word]


# get the game output
def guess_reply(guessing_word, answer):
    reply = [0, 0, 0, 0, 0]
    guessing_word_letters = split_word(guessing_word)
    answer_letters = split_word(answer)
    for letter in guessing_word_letters:
        if letter in answer_letters:
            reply[guessing_word_letters.index(letter)] = 1
        if letter == answer_letters[guessing_word_letters.index(letter)]:
            reply[guessing_word_letters.index(letter)] = 2
    return reply


# 输入一个词和一个回复，从词库中找出所有可能的词
def simu_reply(guessing_word, judged_word, reply):
    # 1:必须在其他位置有
    # 2:必须在相同位置有
    for i in range(5):
        if reply[i] == 1:
            if (
                guessing_word[i] not in judged_word
                or guessing_word[i] == judged_word[i]
            ):
                return False
        if reply[i] == 2:
            if guessing_word[i] != judged_word[i]:
                return False
        if reply[i] == 0:
            if guessing_word[i] in judged_word:
                return False
    return True


# find the possible words in the long_word_list
def find_possible_words(guessing_word, reply):
    possible_words = []
    for word in long_word_list:
        if simu_reply(guessing_word, word, reply):
            possible_words.append(word)
    return possible_words


def find_possible_words_adjusted(guessing_word, reply, possible_words):
    possible_words_reducted = []
    for word in possible_words:
        if simu_reply(guessing_word, word, reply):
            possible_words_reducted.append(word)
    return possible_words_reducted


# calculate the info of the guessing word
def calc_info(guessing_word, reply):
    possible_words = find_possible_words(guessing_word, reply)
    num_of_words = len(possible_words)
    p_x = num_of_words / len(long_word_list)
    return np.log2(1 / p_x)


# calculate the entropy of the guessing word
def calc_E_info(guessing_word):
    E_info = 0
    for reply in reply_list:
        possible_words = find_possible_words(guessing_word, reply)
        p_x = len(possible_words) / len(long_word_list)
        if p_x != 0:
            E_info += p_x * np.log2(1 / p_x)
    return E_info


def calc_E_info_adjusted(guessing_word, possible_words):
    E_info = 0
    total_num = len(possible_words)
    for reply in reply_list:
        possible_words = find_possible_words_adjusted(
            guessing_word, reply, possible_words
        )
        p_x = len(possible_words) / total_num
        if p_x != 0:
            E_info += p_x * np.log2(1 / p_x)
    return E_info

# %%
E_info_for_all_words = pd.DataFrame(columns=["word", "E_info"])

for word in long_word_list:
    E_info_for_all_words.loc[len(E_info_for_all_words)] = [word, calc_E_info(word)]
    print(E_info_for_all_words.loc[len(E_info_for_all_words) - 1])

# 排序
E_info_for_all_words.sort_values(by="E_info", ascending=False, inplace=True)

# 保存
E_info_for_all_words.to_csv("result/E_info_for_all_words.csv", index=False)
# Out:
# word         aahed
# E_info    4.292292
# Name: 0, dtype: object
# word         aalii
# E_info    3.702683
# Name: 1, dtype: object
# word         aargh
# E_info    3.980467
# Name: 2, dtype: object
# word         aarti
# E_info    4.621203
# Name: 3, dtype: object
# word        abaca
# E_info    2.99165
# Name: 4, dtype: object
# word         abaci
# E_info    3.704593
# Name: 5, dtype: object
# word         aback
# E_info    3.330902
# Name: 6, dtype: object
# word         abacs
# E_info    4.162528
# Name: 7, dtype: object
# word         abaft
# E_info    3.468908
# Name: 8, dtype: object
# word         abaka
# E_info    2.885794
# Name: 9, dtype: object
# word         abamp
# E_info    3.390907
# Name: 10, dtype: object
# word         aband
# E_info    3.821515
# Name: 11, dtype: object
# word         abase
# E_info    4.523136
# Name: 12, dtype: object
# word         abash
# E_info    3.882148
# Name: 13, dtype: object
# word         abask
# E_info    3.807766
# Name: 14, dtype: object
# word         abate
# E_info    4.363298
# Name: 15, dtype: object
# word         abaya
# E_info    2.943512
# Name: 16, dtype: object
# word         abbas
# E_info    3.538139
# Name: 17, dtype: object
# word        abbed
# E_info    4.00881
# Name: 18, dtype: object
# word         abbes
# E_info    4.611161
# Name: 19, dtype: object
# word         abbey
# E_info    3.971815
# Name: 20, dtype: object
# word         abbot
# E_info    3.832744
# Name: 21, dtype: object
# word         abcee
# E_info    4.128084
# Name: 22, dtype: object
# word        abeam
# E_info    3.91935
# Name: 23, dtype: object
# word         abear
# E_info    4.322497
# Name: 24, dtype: object
# word         abele
# E_info    4.312743
# Name: 25, dtype: object
# word         abers
# E_info    5.432218
# Name: 26, dtype: object
# word         abets
# E_info    5.327678
# Name: 27, dtype: object
# word         abhor
# E_info    4.455927
# Name: 28, dtype: object
# word         abide
# E_info    4.880477
# Name: 29, dtype: object
# word         abies
# E_info    5.544515
# Name: 30, dtype: object
# word         abled
# E_info    4.906715
# Name: 31, dtype: object
# word         abler
# E_info    5.123663
# Name: 32, dtype: object
# word         ables
# E_info    5.508082
# Name: 33, dtype: object
# word         ablet
# E_info    5.077855
# Name: 34, dtype: object
# word         ablow
# E_info    4.187195
# Name: 35, dtype: object
# word         abmho
# E_info    4.058387
# Name: 36, dtype: object
# word        abode
# E_info    4.86011
# Name: 37, dtype: object
# word         abohm
# E_info    4.103821
# Name: 38, dtype: object
# word         aboil
# E_info    4.751095
# Name: 39, dtype: object
# word         aboma
# E_info    3.736078
# Name: 40, dtype: object
# word         aboon
# E_info    3.896473
# Name: 41, dtype: object
# word         abord
# E_info    4.733388
# Name: 42, dtype: object
# word         abore
# E_info    5.163331
# Name: 43, dtype: object
# word         abort
# E_info    4.861537
# Name: 44, dtype: object
# word         about
# E_info    4.547246
# Name: 45, dtype: object
# word         above
# E_info    4.398444
# Name: 46, dtype: object
# word         abram
# E_info    3.849754
# Name: 47, dtype: object
# word         abray
# E_info    3.955963
# Name: 48, dtype: object
# word         abrim
# E_info    4.590537
# Name: 49, dtype: object
# word         abrin
# E_info    4.810791
# Name: 50, dtype: object
# word         abris
# E_info    5.318351
# Name: 51, dtype: object
# word         absey
# E_info    5.014013
# Name: 52, dtype: object
# word         absit
# E_info    4.928957
# Name: 53, dtype: object
# word         abuna
# E_info    3.735604
# Name: 54, dtype: object
# word        abune
# E_info    4.79685
# Name: 55, dtype: object
# word         abuse
# E_info    5.018449
# Name: 56, dtype: object
# word         abuts
# E_info    4.956823
# Name: 57, dtype: object
# word         abuzz
# E_info    2.821499
# Name: 58, dtype: object
# word         abyes
# E_info    5.167502
# Name: 59, dtype: object
# word         abysm
# E_info    4.259507
# Name: 60, dtype: object
# word         abyss
# E_info    3.968578
# Name: 61, dtype: object
# word         acais
# E_info    4.609721
# Name: 62, dtype: object
# word         acari
# E_info    4.198757
# Name: 63, dtype: object
# word         accas
# E_info    3.662498
# Name: 64, dtype: object
# word         accoy
# E_info    3.772361
# Name: 65, dtype: object
# word         acerb
# E_info    4.719805
# Name: 66, dtype: object
# word         acers
# E_info    5.537681
# Name: 67, dtype: object
# word       aceta
# E_info    4.3001
# Name: 68, dtype: object
# word         achar
# E_info    3.836134
# Name: 69, dtype: object
# word         ached
# E_info    4.622893
# Name: 70, dtype: object
# word         aches
# E_info    5.207212
# Name: 71, dtype: object
# word         achoo
# E_info    3.635233
# Name: 72, dtype: object
# word         acids
# E_info    5.092008
# Name: 73, dtype: object
# word        acidy
# E_info    4.47477
# Name: 74, dtype: object
# word         acing
# E_info    4.396934
# Name: 75, dtype: object
# word         acini
# E_info    3.953421
# Name: 76, dtype: object
# word         ackee
# E_info    4.094346
# Name: 77, dtype: object
# word        acker
# E_info    4.83438
# Name: 78, dtype: object
# word        acmes
# E_info    5.33436
# Name: 79, dtype: object
# word         acmic
# E_info    3.662557
# Name: 80, dtype: object
# word         acned
# E_info    4.971726
# Name: 81, dtype: object
# word         acnes
# E_info    5.552566
# Name: 82, dtype: object
# word         acock
# E_info    3.606071
# Name: 83, dtype: object
# word         acold
# E_info    4.753411
# Name: 84, dtype: object
# word         acorn
# E_info    4.905104
# Name: 85, dtype: object
# word         acred
# E_info    5.175445
# Name: 86, dtype: object
# word         acres
# E_info    5.753354
# Name: 87, dtype: object
# word         acrid
# E_info    4.891657
# Name: 88, dtype: object
# word         acros
# E_info    5.424016
# Name: 89, dtype: object
# word         acted
# E_info    4.965293
# Name: 90, dtype: object
# word         actin
# E_info    4.749325
# Name: 91, dtype: object
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 E_info_for_all_words = pd.DataFrame(columns=['word', 'E_info'])
#       3 for word in long_word_list:
# ----> 4     E_info_for_all_words.loc[len(E_info_for_all_words)] = [word, calc_E_info(word)]
#       5     print(E_info_for_all_words.loc[len(E_info_for_all_words)-1])
#       7 # 排序
#
# Cell In[3], line 59, in calc_E_info(guessing_word)
#      57 E_info = 0
#      58 for reply in reply_list:
# ---> 59     possible_words = find_possible_words(guessing_word, reply)
#      60     p_x = len(possible_words) / len(long_word_list)
#      61     if p_x != 0:
#
# Cell In[3], line 37, in find_possible_words(guessing_word, reply)
#      35 possible_words = []
#      36 for word in long_word_list:
# ---> 37     if simu_reply(guessing_word,word,reply):
#      38         possible_words.append(word)
#      39 return possible_words
#
# Cell In[3], line 22, in simu_reply(guessing_word, judged_word, reply)
#      18 def simu_reply(guessing_word,judged_word,reply):
#      19     # 1:必须在其他位置有
#      20     # 2:必须在相同位置有
#      21     for i in range(5):
# ---> 22         if reply[i] == 1:
#      23             if guessing_word[i] not in judged_word or guessing_word[i] == judged_word[i]:
#      24                 return False
#
# KeyboardInterrupt:

# %%
# # Wordle game
# # roll an answer
# ANSWER = np.random.choice(short_word_list)
# ANSWER = 'state'

# game_reply = {}
# possible_words_list = {}
# num_possible_words = {}
# guessing_word = {}

# # game solution1: use the word has the highest E_info satisfied the reply every time
# def solution1(start_word):
#     if start_word == '':
#         start_word = 'trane'

#     game_reply = {}
#     guessing_word = {}

#     guessing_word[0] = start_word
#     possible_words=long_word_list
#     turn=0

#     while True:
#         game_reply[turn] = guess_reply(guessing_word[turn], ANSWER)
#         print(turn,guessing_word[turn],game_reply[turn])

#         possible_words= find_possible_words_adjusted(guessing_word[turn],
#                                                 game_reply[turn],
#                                                 possible_words)
#         E_info_for_possible_words = pd.DataFrame(columns=['word', 'E_info'])
#         for word in possible_words:
#             E_info_for_possible_words.loc[len(E_info_for_possible_words)] = [word, calc_E_info_adjusted(word,possible_words)]
#         E_info_for_possible_words.sort_values(by='E_info', ascending=False, inplace=True)
#         guessing_word[turn+1]=E_info_for_possible_words['word'][0]

#         if guessing_word[turn+1]==ANSWER:
#             print(ANSWER)
#             break

#         turn+=1

#     return guessing_word

# solution1('')
# Out:
# 0 trane [1, 0, 2, 0, 2]
# 1 abate [1, 0, 0, 2, 2]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Documents/Wordle/.venv/lib/python3.9/site-packages/pandas/core/indexes/range.py:345, in RangeIndex.get_loc(self, key)
#     344 try:
# --> 345     return self._range.index(new_key)
#     346 except ValueError as err:
#
# ValueError: 0 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[163], line 44
#      40         turn+=1
#      42     return guessing_word
# ---> 44 solution1('')
#
# Cell In[163], line 34, in solution1(start_word)
#      32     E_info_for_possible_words.loc[len(E_info_for_possible_words)] = [word, calc_E_info_adjusted(word,possible_words)]
#      33 E_info_for_possible_words.sort_values(by='E_info', ascending=False, inplace=True)
# ---> 34 guessing_word[turn+1]=E_info_for_possible_words['word'][0]
#      36 if guessing_word[turn+1]==ANSWER:
#      37     print(ANSWER)
#
# File ~/Documents/Wordle/.venv/lib/python3.9/site-packages/pandas/core/series.py:1007, in Series.__getitem__(self, key)
#    1004     return self._values[key]
#    1006 elif key_is_scalar:
# -> 1007     return self._get_value(key)
#    1009 if is_hashable(key):
#    1010     # Otherwise index.get_value will raise InvalidIndexError
#    1011     try:
#    1012         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~/Documents/Wordle/.venv/lib/python3.9/site-packages/pandas/core/series.py:1116, in Series._get_value(self, label, takeable)
#    1113     return self._values[label]
#    1115 # Similar to Index.get_value, but we do not fall back to positional
# -> 1116 loc = self.index.get_loc(label)
#    1118 if is_integer(loc):
#    1119     return self._values[loc]
#
# File ~/Documents/Wordle/.venv/lib/python3.9/site-packages/pandas/core/indexes/range.py:347, in RangeIndex.get_loc(self, key)
#     345         return self._range.index(new_key)
#     346     except ValueError as err:
# --> 347         raise KeyError(key) from err
#     348 if isinstance(key, Hashable):
#     349     raise KeyError(key)
#
# KeyError: 0
